# %%
import nltk #import library nltk
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
from nltk.tokenize import sent_tokenize #import sent_tokenize for tokenizing paragraph into sentences
from nltk.stem.porter import PorterStemmer #import Porter Stemmer Algorithm 
from nltk.stem import WordNetLemmatizer #import WordNet lemmatizer 
from nltk.corpus import stopwords #import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
import re #import regular expression
from nltk.tokenize import RegexpTokenizer
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from collections import Counter
from nltk.corpus import wordnet

# %%
#casefolding
def casefolding(s):
    new_str = s.lower()
    return new_str

#remove punctuation from string
def removepunct(str):
    new_string =  re.sub(r"[\W]", " ", str)
    return new_string

#stopwords
def stpwrds(str):
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(str) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words]  
    filtered_sentence = [] 
    
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w)
    return filtered_sentence

#Lemmatization
def lemmaeng(str):
    wordnet_lemmatizer = WordNetLemmatizer()
    word_data = str
    nltk_tokens = nltk.word_tokenize(word_data)

    for w in nltk_tokens:
        print ("Actual: %s  Lemma: %s"  % (w,wordnet_lemmatizer.lemmatize(w)))

# %%
def main():
    file = open('artikel2.txt', 'r')
    text_data = file.read()
    cf = casefolding(text_data)
    rp = removepunct(cf)
    filt = stpwrds(rp)
    par = ' '.join(filt)
    result = lemmaeng(par)    
    print(result)
    
if __name__== "__main__":
    main()
# Out:
# Actual: team  Lemma: team
# Actual: indonesian  Lemma: indonesian
# Actual: students  Lemma: student
# Actual: place  Lemma: place
# Actual: second  Lemma: second
# Actual: korea  Lemma: korea
# Actual: open  Lemma: open
# Actual: memory  Lemma: memory
# Actual: championship  Lemma: championship
# Actual: group  Lemma: group
# Actual: indonesian  Lemma: indonesian
# Actual: students  Lemma: student
# Actual: brought  Lemma: brought
# Actual: home  Lemma: home
# Actual: two  Lemma: two
# Actual: gold  Lemma: gold
# Actual: medals  Lemma: medal
# Actual: two  Lemma: two
# Actual: silvers  Lemma: silver
# Actual: two  Lemma: two
# Actual: bronzes  Lemma: bronze
# Actual: recent  Lemma: recent
# Actual: second  Lemma: second
# Actual: korea  Lemma: korea
# Actual: open  Lemma: open
# Actual: memory  Lemma: memory
# Actual: championship  Lemma: championship
# Actual: held  Lemma: held
# Actual: seoul  Lemma: seoul
# Actual: south  Lemma: south
# Actual: korea  Lemma: korea
# Actual: held  Lemma: held
# Actual: aug  Lemma: aug
# Actual: 25  Lemma: 25
# Actual: 26  Lemma: 26
# Actual: event  Lemma: event
# Actual: also  Lemma: also
# Actual: included  Lemma: included
# Actual: students  Lemma: student
# Actual: south  Lemma: south
# Actual: korea  Lemma: korea
# Actual: mongolia  Lemma: mongolia
# Actual: china  Lemma: china
# Actual: japan  Lemma: japan
# Actual: united  Lemma: united
# Actual: kingdom  Lemma: kingdom
# Actual: libya  Lemma: libya
# Actual: moldova  Lemma: moldova
# Actual: team  Lemma: team
# Actual: indonesian  Lemma: indonesian
# Actual: students  Lemma: student
# Actual: nabbing  Lemma: nabbing
# Actual: second  Lemma: second
# Actual: place  Lemma: place
# Actual: reported  Lemma: reported
# Actual: kompas  Lemma: kompas
# Actual: com  Lemma: com
# Actual: held  Lemma: held
# Actual: global  Lemma: global
# Actual: convention  Lemma: convention
# Actual: plaza  Lemma: plaza
# Actual: main  Lemma: main
# Actual: auditorium  Lemma: auditorium
# Actual: seoul  Lemma: seoul
# Actual: national  Lemma: national
# Actual: university  Lemma: university
# Actual: event  Lemma: event
# Actual: 10  Lemma: 10
# Actual: competitions  Lemma: competition
# Actual: memorization  Lemma: memorization
# Actual: skills  Lemma: skill
# Actual: ranging  Lemma: ranging
# Actual: five  Lemma: five
# Actual: minute  Lemma: minute
# Actual: 15  Lemma: 15
# Actual: minute  Lemma: minute
# Actual: categories  Lemma: category
# Actual: remembering  Lemma: remembering
# Actual: various  Lemma: various
# Actual: things  Lemma: thing
# Actual: numbers  Lemma: number
# Actual: cards  Lemma: card
# Actual: well  Lemma: well
# Actual: pairing  Lemma: pairing
# Actual: faces  Lemma: face
# Actual: names  Lemma: name
# Actual: years  Lemma: year
# Actual: events  Lemma: event
# Actual: indonesian  Lemma: indonesian
# Actual: team  Lemma: team
# Actual: participated  Lemma: participated
# Actual: guidance  Lemma: guidance
# Actual: indonesia  Lemma: indonesia
# Actual: memory  Lemma: memory
# Actual: sport  Lemma: sport
# Actual: council  Lemma: council
# Actual: led  Lemma: led
# Actual: international  Lemma: international
# Actual: grandmaster  Lemma: grandmaster
# Actual: memory  Lemma: memory
# Actual: yudi  Lemma: yudi
# Actual: lesmana  Lemma: lesmana
# Actual: biggest  Lemma: biggest
# Actual: winner  Lemma: winner
# Actual: yogyakarta  Lemma: yogyakarta
# Actual: kesatuan  Lemma: kesatuan
# Actual: bangsa  Lemma: bangsa
# Actual: junior  Lemma: junior
# Actual: high  Lemma: high
# Actual: school  Lemma: school
# Actual: smp  Lemma: smp
# Actual: student  Lemma: student
# Actual: shafa  Lemma: shafa
# Actual: annisa  Lemma: annisa
# Actual: took  Lemma: took
# Actual: home  Lemma: home
# Actual: one  Lemma: one
# Actual: gold  Lemma: gold
# Actual: one  Lemma: one
# Actual: silver  Lemma: silver
# Actual: one  Lemma: one
# Actual: bronze  Lemma: bronze
# Actual: medal  Lemma: medal
# Actual: farah  Lemma: farah
# Actual: afifah  Lemma: afifah
# Actual: pulungan  Lemma: pulungan
# Actual: sman  Lemma: sman
# Actual: 1  Lemma: 1
# Actual: depok  Lemma: depok
# Actual: one  Lemma: one
# Actual: gold  Lemma: gold
# Actual: competition  Lemma: competition
# Actual: amira  Lemma: amira
# Actual: tsurayya  Lemma: tsurayya
# Actual: muniruzaman  Lemma: muniruzaman
# Actual: sma  Lemma: sma
# Actual: pesantren  Lemma: pesantren
# Actual: al  Lemma: al
# Actual: bayan  Lemma: bayan
# Actual: sukabumi  Lemma: sukabumi
# Actual: one  Lemma: one
# Actual: silver  Lemma: silver
# Actual: zara  Lemma: zara
# Actual: tabina  Lemma: tabina
# Actual: smpit  Lemma: smpit
# Actual: aulady  Lemma: aulady
# Actual: bsd  Lemma: bsd
# Actual: south  Lemma: south
# Actual: tangerang  Lemma: tangerang
# Actual: bronze  Lemma: bronze
# Actual: medal  Lemma: medal
# Actual: among  Lemma: among
# Actual: outstanding  Lemma: outstanding
# Actual: achievements  Lemma: achievement
# Actual: include  Lemma: include
# Actual: gold  Lemma: gold
# Actual: medal  Lemma: medal
# Actual: winner  Lemma: winner
# Actual: shafa  Lemma: shafa
# Actual: memorized  Lemma: memorized
# Actual: 100  Lemma: 100
# Actual: random  Lemma: random
# Actual: numbers  Lemma: number
# Actual: recited  Lemma: recited
# Actual: within  Lemma: within
# Actual: 100  Lemma: 100
# Actual: seconds  Lemma: second
# Actual: meanwhile  Lemma: meanwhile
# Actual: fellow  Lemma: fellow
# Actual: gold  Lemma: gold
# Actual: medalist  Lemma: medalist
# Actual: farah  Lemma: farah
# Actual: able  Lemma: able
# Actual: remember  Lemma: remember
# Actual: 47  Lemma: 47
# Actual: faces  Lemma: face
# Actual: names  Lemma: name
# Actual: random  Lemma: random
# Actual: order  Lemma: order
# Actual: within  Lemma: within
# Actual: five  Lemma: five
# Actual: minute  Lemma: minute
# Actual: time  Lemma: time
# Actual: allotted  Lemma: allotted
# Actual: silver  Lemma: silver
# Actual: medal  Lemma: medal
# Actual: winner  Lemma: winner
# Actual: amira  Lemma: amira
# Actual: able  Lemma: able
# Actual: remember  Lemma: remember
# Actual: 77  Lemma: 77
# Actual: words  Lemma: word
# Actual: order  Lemma: order
# Actual: within  Lemma: within
# Actual: five  Lemma: five
# Actual: minutes  Lemma: minute
# Actual: bronze  Lemma: bronze
# Actual: medal  Lemma: medal
# Actual: winner  Lemma: winner
# Actual: zara  Lemma: zara
# Actual: memorized  Lemma: memorized
# Actual: 198  Lemma: 198
# Actual: images  Lemma: image
# Actual: random  Lemma: random
# Actual: order  Lemma: order
# Actual: within  Lemma: within
# Actual: five  Lemma: five
# Actual: minutes  Lemma: minute
# Actual: remarkable  Lemma: remarkable
# Actual: achievement  Lemma: achievement
# Actual: students  Lemma: student
# Actual: proved  Lemma: proved
# Actual: memory  Lemma: memory
# Actual: extraordinary  Lemma: extraordinary
# Actual: ari  Lemma: ari
# Actual: santoso  Lemma: santoso
# Actual: education  Lemma: education
# Actual: culture  Lemma: culture
# Actual: ministry  Lemma: ministry
# Actual: head  Lemma: head
# Actual: communications  Lemma: communication
# Actual: public  Lemma: public
# Actual: relations  Lemma: relation
# Actual: bureau  Lemma: bureau
# Actual: said  Lemma: said
# Actual: recently  Lemma: recently
# Actual: congratulating  Lemma: congratulating
# Actual: participants  Lemma: participant
# None
